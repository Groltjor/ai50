# %%
import pandas as pd


data_check = pd.read_csv("harvard_dimension/heredity/data/family0.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 4
#       1 import pandas as pd
# ----> 4 data_check = pd.open_csv("harvard_dimension/heredity/data/family0.csv")
#
# AttributeError: module 'pandas' has no attribute 'open_csv'

# %%
data_check.head()
